# %% [markdown]
# #Excel Besics
#
# 1. Explain the differnce between Relative,Absolute, And Mixed Cell Referencing .
# You have the following detaset.
#
# ->
# **RElative Reference**
#
# -Example: A1
# -Change automatically when you copy the formula.
# -If you copy =A1+b1 down, it becomes =A2+B2
#
# **Absolute REference**
#
# -Example: $A$1
# -Does not change when copied.
# -Always fixed to the cell.
#
# **MIxed cell**
#
# -Example: $A1 or A$1
# -One part fixed,one part changes:
#     -$A1 -> column fixed,row changes.
#     -A$1 -> row fixed,column changes.
#
#  2.Formula to calculate total sales of car and bicycle.
#  ->
#  Asume;
#  -Car price -> B2
#  -Bicycle price -> B3
#  **FOrmula -> =B2+B3**
#
# ** Output** : 500000 + 10500 = 510500
#
# 3. Formula to calculate average sales of items priced above 100 but less then 300.
# Item  Price  Sales
#  A     90     1000
#  B     150    1200
#  C     250    1500
# ->
# From the table:
#
# - 150 and 250 are the price greater then 100 and less then 300.
#
# Average = (1200 + 1500)/2
# -> 1350
#
# Excel formula:
# = AVERAGEIFS(C2:C4, B2:B4, ">100", B2:B4, "<300")
#
# NOTE: Use the dataset for next questions.
#
# 4.Count how many customer names are recorded.
# -> Formula for count name is:-  =COUNTA(B2:B51)
# Answer is 51.
#
# 5.Calculate the total sales for each row using a formula.
# ->
# First we have to multiply total quantity and total unit sold.
#
# H2-> =(E2*F2) for total sale of a produce.
# now drag the h2 for all the product sale.
# And Now,
# Total sale-> =SUM(H2:H51)
# -> 16543
#
# 6. Calculate the total sales of Notebook  in the North region only.
# ->
# First we short the North region
# After this apply the sum formula
# =SUM(h2:H51)
# 4941
#
# 7.Create a column chart showing total sales by product.
# -> for creating total sale by product we use formula in H2
# =(E2*F2)
# and drag to H51.
# now using sum formula
# =SUM(H2:H51)
# Result= 16293
#
# 8.Insert a line chart showing daily sale Trend.
# ->

# %% [markdown]
# ## New Section
